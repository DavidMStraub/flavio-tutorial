# %%
import flavio
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# # flavio tutorial
#
# ## Test
#
# by David M. Straub

# %% [markdown]
# ### Test

# %%
import flavio.plots as fpl
import matplotlib.pyplot as plt
fpl.bin_plot_exp('<BR>(B0->D*lnu)', divide_binwidth=True, )
plt.xlabel(r'$q^2$')
plt.ylabel(flavio.Observable['<BR>(B0->D*lnu)'].tex)
